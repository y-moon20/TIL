# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136873&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1'
html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')

import ssl
context = ssl._create_unverified_context()

url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136873&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1'
html = urlopen(url, context=context)
soup = BeautifulSoup(html,'html.parser')

# %%
review = soup.find('span',{'id':'_filtered_ment_0'})
review.get_text().strip()
# Out:
# '올라프의 1편요약이 기가맥힙니다'

# %%
for i in range(10):
    star = soup.select('div.score_result>ul>li>div.star_score>em')[i]
    print(star.get_text())
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
for i in range(10):
    review = soup.find('span',{'id':f'_filtered_ment_{i}'})
    print(f'{i+1} 번째 리뷰')
    print(review.get_text().strip())
    print('--------------------')
# Out:
# 1 번째 리뷰
# 올라프의 1편요약이 기가맥힙니다
# --------------------
# 2 번째 리뷰
# 크리스토퍼 뮤비에서 좀 흠칫함
# --------------------
# 3 번째 리뷰
# 미래가 보이지 않을 때는 지금 해야할 일을 해야 해
# --------------------
# 4 번째 리뷰
# 나는 개인적으로 2편이 더 좋았음. 더 깊어진 스토리에 아름다워진 영상미. 한번 더 볼 의향 있음.
# --------------------
# 5 번째 리뷰
# 엘사옷 보고 어머니들 긴장하는 영화
# --------------------
# 6 번째 리뷰
# 애기들 울고 떠들고 하는거 보고 엘사 마법으로 얼릴뻔 했네요
# --------------------
# 7 번째 리뷰
# 크리스토퍼 혹시 과거에 뮤비찍어본적 있니?왜 이렇게 잘해??...순간 당황했잖아
# --------------------
# 8 번째 리뷰
# 백마탄 엘사님 Show yourself 장면 진짜 개오집니다 단언컨데 제2의 렛잇고는 into the unknown 아니고 Show yourself 입니다
# --------------------
# 9 번째 리뷰
# 엘사 물 속에서 말타고 나올 때 대박ㅋㅋㅋㅋ
# --------------------
# 10 번째 리뷰
# 겨울왕국 역시는 역시였다. OST도 1편만큼이나 중독성있다고 생각함ㅋㅋㅋ1편만큼 존잼임
# --------------------

# %%
star_list = []
review_list = []
for page in range(1,2384):
    url = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136873&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={page}'
    html = urlopen(url)
    soup = BeautifulSoup(html,'html.parser')
    print(f'{page} 하는 중')
    for i in range(10):
        review = soup.find('span',{'id':f'_filtered_ment_{i}'})
        review = review.get_text().strip()
        star = soup.select('div.score_result>ul>li>div.star_score>em')[i]
        star = star.get_text()
        review_list.append(review)
        star_list.append(star)
# Out:
# 1 하는 중
# 2 하는 중
# 3 하는 중
# 4 하는 중
# 5 하는 중
# 6 하는 중
# 7 하는 중
# 8 하는 중
# 9 하는 중
# 10 하는 중
# 11 하는 중
# 12 하는 중
# 13 하는 중
# 14 하는 중
# 15 하는 중
# 16 하는 중
# 17 하는 중
# 18 하는 중
# 19 하는 중
# 20 하는 중
# 21 하는 중
# 22 하는 중
# 23 하는 중
# 24 하는 중
# 25 하는 중
# 26 하는 중
# 27 하는 중
# 28 하는 중
# 29 하는 중
# 30 하는 중
# 31 하는 중
# 32 하는 중
# 33 하는 중
# 34 하는 중
# 35 하는 중
# 36 하는 중
# 37 하는 중
# 38 하는 중
# 39 하는 중
# 40 하는 중
# 41 하는 중
# 42 하는 중
# 43 하는 중
# 44 하는 중
# 45 하는 중
# 46 하는 중
# 47 하는 중
# 48 하는 중
# 49 하는 중
# 50 하는 중
# 51 하는 중
# 52 하는 중
# 53 하는 중
# 54 하는 중
# 55 하는 중
# 56 하는 중
# 57 하는 중
# 58 하는 중
# 59 하는 중
# 60 하는 중
# 61 하는 중
# 62 하는 중
# 63 하는 중
# 64 하는 중
# 65 하는 중
# 66 하는 중
# 67 하는 중
# 68 하는 중
# 69 하는 중
# 70 하는 중
# 71 하는 중
# 72 하는 중
# 73 하는 중
# 74 하는 중
# 75 하는 중
# 76 하는 중
# 77 하는 중
# 78 하는 중
# 79 하는 중
# 80 하는 중
# 81 하는 중
# 82 하는 중
# 83 하는 중
# 84 하는 중
# 85 하는 중
# 86 하는 중
# 87 하는 중
# 88 하는 중
# 89 하는 중
# 90 하는 중
# 91 하는 중
# 92 하는 중
# 93 하는 중
# 94 하는 중
# 95 하는 중
# 96 하는 중
# 97 하는 중
# 98 하는 중
# 99 하는 중
# 100 하는 중
# ...

# %%
count = list(range(1,len(star_list)+1))

# %%
import pandas as pd
columns = ['star']
df = pd.DataFrame(star_list,
                 index = count,
                 columns = columns)
df['review'] = review_list

# %%
df
# Out:
#       star                                             review
# 1       10                                  올라프의 1편요약이 기가맥힙니다
# 2       10                                   크리스토퍼 뮤비에서 좀 흠칫함
# 3       10                       미래가 보이지 않을 때는 지금 해야할 일을 해야 해
# 4       10  나는 개인적으로 2편이 더 좋았음. 더 깊어진 스토리에 아름다워진 영상미. 한번 더...
# 5       10                                엘사옷 보고 어머니들 긴장하는 영화
# ...    ...                                                ...
# 23826    1                          남는게 1도 없는 영화 중간에 화장실 가도 됨
# 23827    1      1편도 별감흥없엇는데 2편은 더 재미없다 노래도 별로고  노래만 주구장창나옴 ㅅ벌
# 23828    1  노래, 스토리 다좋았으나 엘사랑 안나 가슴이 너무작은게 큰단점이다.... 여캐답게 ...
# 23829    1                           몰입 안되는 스토리ㅋㅋㅋ 드럽게 재미없네ㅋㅋ
# 23830    2  진짜 이름에 비해 값어치 드럽게 못하는 저질 영화 스크린 독점이나 하고 앉아있고 그...
#
# [23830 rows x 2 columns]

# %%
df.to_csv('겨울왕국.csv')
